# %%
bot_template = "BOT : {0}"
user_template = "USER : {0}"
import random
import re

# Define a function that sends a message to the bot: send_message
def send_message(message):
    # Print user_template including the user_message
    print(user_template.format(message))
    # Get the bot's response to the message
    response = respond(message)
    # Print the bot template including the bot's response.
    print(bot_template.format(response))
    
rules = {'I want (.*)': ['What would it mean if you got {0}', 
                         'Why do you want {0}', 
                         "What's stopping you from getting {0}"], 
         'do you remember (.*)': ['Did you think I would forget {0}', 
                                  "Why haven't you been able to forget {0}", 
                                  'What about {0}', 
                                  'Yes .. and?'], 
         'do you think (.*)': ['if {0}? Absolutely.',
                               'No chance'],
         'what if (.*)': ["Do you really think it's likely that {0}",
                     'Do you wish that {0}', 
                     'What do you think about {0}',
                     'Really--if {0}']
        }

# Define match_rule()
def match_rule(rules, message):
    response, phrase = "default", None
    
    # Iterate over the rules dictionary
    for key, value in rules.items():
        # Create a match object
        match = re.match(key,message)
        if match is not None:
            # Choose a random response
            response = random.choice(value)
            if '{0}' in response:
                phrase = match.group(1)
    # Return the response and phrase
    return response, phrase

# Test match_rule
print(match_rule(rules, "do you remember your last birthday"))

# Define replace_pronouns()
def replace_pronouns(message):

    message = message.lower()
    if 'me' in message:
        # Replace 'me' with 'you'
        return message.replace("me","you")
    if 'my' in message:
        # Replace 'my' with 'your'
        return message.replace("my","your")
    if 'your' in message:
        # Replace 'your' with 'my'
        return message.replace("your","my")
    if 'you' in message:
        # Replace 'you' with 'me'
        return message.replace("you","me")

    return message

print(replace_pronouns("my last birthday"))
print(replace_pronouns("when you went to Florida"))
print(replace_pronouns("I had my own castle"))

# Define respond()
def respond(message):
    # Call match_rule
    reponse, phrase = match_rule(rules,message)
    if '{0}' in response:
        # Replace the pronouns in the phrase
        phrase = replace_pronouns(phrase)
        # Include the phrase in the response
        response = reponse.format(phrase)
    return response

# Send the messages
send_message("do you remember your last birthday")
send_message("do you think humans should be worried about AI")
send_message("I want a robot friend")
send_message("what if you could be anything you wanted")
# Out:
# ('Did you think I would forget {0}', 'your last birthday')
# your last birthday
# when me went to florida
# i had your own castle
# USER : do you remember your last birthday
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-3-ed99034d0c93> in <module>()
#      82
#      83 # Send the messages
# ---> 84 send_message("do you remember your last birthday")
#      85 send_message("do you think humans should be worried about AI")
#      86 send_message("I want a robot friend")
#
# <ipython-input-3-ed99034d0c93> in send_message(message)
#       9     print(user_template.format(message))
#      10     # Get the bot's response to the message
# ---> 11     response = respond(message)
#      12     # Print the bot template including the bot's response.
#      13     print(bot_template.format(response))
#
# <ipython-input-3-ed99034d0c93> in respond(message)
#      74     # Call match_rule
#      75     reponse, phrase = match_rule(rules,message)
# ---> 76     if '{0}' in response:
#      77         # Replace the pronouns in the phrase
#      78         phrase = replace_pronouns(phrase)
#
# UnboundLocalError: local variable 'response' referenced before assignment
